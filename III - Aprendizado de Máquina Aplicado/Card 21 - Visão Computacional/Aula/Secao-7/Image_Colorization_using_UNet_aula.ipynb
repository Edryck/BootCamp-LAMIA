# %%
# !pip install torch_snippets
from torch_snippets import *
device = 'cuda' if torch.cuda.is_available else 'cpu'
# Out:
# Requirement already satisfied: torch_snippets in /usr/local/lib/python3.13/dist-packages (0.560)
# Requirement already satisfied: plum-dispatch in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.9.0)
# Requirement already satisfied: fastcore in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.2.14)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (3.10.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (11.3.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.3.8)
# Requirement already satisfied: loguru in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.1.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.2.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (4.67.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (13.9.4)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (6.0.3)
# Requirement already satisfied: catalogue in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.0.10)
# Requirement already satisfied: confection in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (1.3.3)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.13.4)
# Requirement already satisfied: typing in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (3.7.4.3)
# Requirement already satisfied: srsly in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.5.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (4.16.0)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (1.1.3)
# Requirement already satisfied: jsonlines in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (4.0.0)
# Requirement already satisfied: imgaug>=0.4.0 in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.4.0)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (1.0.4)
# Requirement already satisfied: fuzzywuzzy in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.18.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (3.9.1)
# Requirement already satisfied: python-Levenshtein in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.27.4)
# Requirement already satisfied: pre-commit in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (4.6.2)
# Requirement already satisfied: icecream in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.2.0)
# Requirement already satisfied: mergedeep in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (1.3.4)
# Requirement already satisfied: deepdiff in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (9.1.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.27.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (2.11.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.26.0+cpu)
# Requirement already satisfied: lovely_tensors in /usr/local/lib/python3.13/dist-packages (from torch_snippets) (0.1.22)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (1.16.3)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (0.25.2)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (5.0.0.93)
# Requirement already satisfied: imageio in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (2.37.4)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.13/dist-packages (from imgaug>=0.4.0->torch_snippets) (2.1.2)
# Requirement already satisfied: cachebox<6,>=5.2 in /usr/local/lib/python3.13/dist-packages (from deepdiff->torch_snippets) (5.2.3)
# Requirement already satisfied: orderly-set<6,>=5.5.0 in /usr/local/lib/python3.13/dist-packages (from deepdiff->torch_snippets) (5.5.0)
# Requirement already satisfied: colorama>=0.3.9 in /usr/local/lib/python3.13/dist-packages (from icecream->torch_snippets) (0.4.6)
# Requirement already satisfied: pygments>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from icecream->torch_snippets) (2.21.0)
# Requirement already satisfied: executing>=2.1.0 in /usr/local/lib/python3.13/dist-packages (from icecream->torch_snippets) (2.2.1)
# Requirement already satisfied: asttokens>=2.0.1 in /usr/local/lib/python3.13/dist-packages (from icecream->torch_snippets) (3.0.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonlines->torch_snippets) (26.1.0)
# Requirement already satisfied: lovely-numpy>=0.2.20 in /usr/local/lib/python3.13/dist-packages (from lovely_tensors->torch_snippets) (0.2.24)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (26.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->torch_snippets) (2.9.0.post0)
# Requirement already satisfied: click in /usr/local/lib/python3.13/dist-packages (from nltk->torch_snippets) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.13/dist-packages (from nltk->torch_snippets) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.13/dist-packages (from nltk->torch_snippets) (2025.11.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->torch_snippets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->torch_snippets) (2026.3)
# Requirement already satisfied: beartype>=0.16.2 in /usr/local/lib/python3.13/dist-packages (from plum-dispatch->torch_snippets) (0.22.9)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich->torch_snippets) (4.2.0)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from pre-commit->torch_snippets) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from pre-commit->torch_snippets) (2.6.19)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.13/dist-packages (from pre-commit->torch_snippets) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.13/dist-packages (from pre-commit->torch_snippets) (21.7.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->torch_snippets) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic->torch_snippets) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic->torch_snippets) (0.4.4)
# Requirement already satisfied: Levenshtein==0.27.4 in /usr/local/lib/python3.13/dist-packages (from python-Levenshtein->torch_snippets) (0.27.4)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /usr/local/lib/python3.13/dist-packages (from Levenshtein==0.27.4->python-Levenshtein->torch_snippets) (3.14.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (3.32.4)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.13/dist-packages (from torch->torch_snippets) (2025.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->torch_snippets) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->torch_snippets) (0.0.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich->torch_snippets) (0.1.2)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch_snippets) (2026.8.23)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.13/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4.0->torch_snippets) (0.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch->torch_snippets) (1.3.0)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.13/dist-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (0.4.3)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.13/dist-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (4.11.4)
# Requirement already satisfied: python-discovery>=1.4.2 in /usr/local/lib/python3.13/dist-packages (from virtualenv>=20.10.0->pre-commit->torch_snippets) (1.5.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch->torch_snippets) (3.0.3)

# %%
from torchvision import datasets
import torch
data_folder = '~/cifar10/cifar/'
datasets.CIFAR10(data_folder, download=True)
# Out:
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: /root/cifar10/cifar/
#     Split: Train

# %%
class Colorize(torchvision.datasets.CIFAR10):
  def __init__(seçf, root, train):
    super().__init__(root, train)

  def __getitem__(self, ix):
    im, _ = super().__getitem__(ix)
    bw = im.convert('L').convert('RGB')
    bw, im = np.array(bw)/255., np.array(im)/255.
    bw, im = [torch.tensor(i).permute(2,0,1).to(device).float() for i in [bw,im]]
    return bw, im

trn_ds = Colorize('~/cifar10/cifar/', train=True)
val_ds = Colorize('~/cifar10/cifar/', train=False)

trn_dl = DataLoader(trn_ds, batch_size=256, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=256, shuffle=False)

# %%
a,b = trn_ds[0]
subplots([a,b], nc=2)

# %%
class Identity(nn.Module):
  def __init__(self):
    super().__init__()
  def forward(self, x):
    return x

class DownConv(nn.Module):
  def __init__(self, ni, no, maxpool=True):
    super().__init__()
    self.model = nn.Sequential(
    nn.MaxPool2d(2) if maxpool else Identity(), nn.Conv2d(ni, no, 3, padding=1),
    nn.BatchNorm2d(no),
    nn.LeakyReLU(0.2, inplace=True), nn.Conv2d(no, no, 3, padding=1), nn.BatchNorm2d(no),
    nn.LeakyReLU(0.2, inplace=True),
  )
  def forward(self, x):
    return self.model(x)
class UpConv(nn.Module):
  def __init__(self, ni, no, maxpool=True):
    super().__init__()
    self.convtranspose = nn.ConvTranspose2d(ni, no, 2, stride=2)
    self.convlayers = nn. Sequential(
      nn.Conv2d(no+no, no, 3, padding=1),
      nn.BatchNorm2d(no),
      nn.LeakyReLU(0.2, inplace=True),
      nn.Conv2d(no, no, 3, padding=1),
      nn.BatchNorm2d(no),
      nn.LeakyReLU(0.2, inplace=True),
    )

  def forward(self, x, y):
    x = self.convtranspose(x)
    x = torch.cat([x,y], axis=1)
    x = self.convlayers(x)
    return x

class UNet (nn.Module):
  def __init__(self):
    super().__init__()
    self.d1 = DownConv(3, 64, maxpool=False)
    self.d2 = DownConv( 64, 128)
    self.d3 = DownConv( 128, 256)
    self.d4 = DownConv( 256, 512)
    self.d5 = DownConv( 512, 1024)
    self.u5 = UpConv (1024, 512)
    self.u4 = UpConv (512, 256)
    self.u3 = UpConv (256, 128)
    self.u2 = UpConv ( 128, 64)
    self.u1 = nn.Conv2d(64, 3, kernel_size=1, stride=1)
  def forward(self, x):
    x0 = self.d1(x) # 32
    x1 = self.d2(x0) # 16
    x2 = self.d3(x1) # 8
    x3 = self.d4(x2) # 4
    x4 = self.d5(x3) #2
    X4 = self.u5(x4, x3)# 4
    X3 = self.u4(X4, x2)# 8
    X2 = self.u3(X3, x1)# 16
    X1 = self.u2(X2, x0)# 32
    X0 = self.u1(X1) # 3
    return X0

# %%
def get_model():
  model = UNet().to(device)
  optimizer = optim.Adam(model.parameters(), lr=1e-3)
  loss_fn = nn.MSELoss()
  return model, optimizer, loss_fn

# %%
def train_batch(model, data, optimizer, criterion):
  model.train()
  x, y = data
  _y = model(x)
  optimizer.zero_grad()
  loss = criterion(_y, y)
  loss.backward()
  optimizer.step()
  return loss.item()

@torch.no_grad()
def validate_batch (model, data, criterion):
  model.eval()
  x, y = data
  _y = model(x)
  loss = criterion(_y, y)
  return loss.item()

# %%
model, optimizer, criterion = get_model()
exp_lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

_val_dl = DataLoader (val_ds, batch_size=1, shuffle=True)

n_epochs = 100
log = Report (n_epochs)
for ex in range(n_epochs):
  N = len(trn_dl)
  for bx, data in enumerate(trn_dl):
    loss = train_batch(model, data, optimizer, criterion)
    log.record(ex+(bx+1)/N, trn_loss=loss, end='\r')
    if (bx+1)%50 == 0:
      for _ in range(5):
        a,b = next(iter(_val_dl))
        _b = model(a)
        subplots([a[0], b[0], _b[0]], nc=3, figsize=(5,5))
  N = len(val_dl)
  for bx, data in enumerate(val_dl):
    loss = validate_batch(model, data, criterion)
    log.record(ex+(bx+1)/N, val_loss=loss, end='\n')

  exp_lr_scheduler.step()
  if (ex+1)% 5 == 0: log.report_avgs(ex+1)

  for _ in range(5):
    a,b = next(iter(_val_dl))
    _b = model(a)
    subplots([a[0], b[0]], c=3, figsize=(5,5))

log.plot(log=True)
# Out:
# EPOCH: 0.255  trn_loss: 0.008  (1738.95s - 679929.63s remaining)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.20291163..1.3532436].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.25837573..1.4317708].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.16538863..1.3125725].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.08106614..1.5423119].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.1756168..1.4587879].
